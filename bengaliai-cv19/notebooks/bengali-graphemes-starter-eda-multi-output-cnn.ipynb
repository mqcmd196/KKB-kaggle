# %%
from google.colab import drive
drive.mount('/content/gdrive/')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive/

# %%
# %cd gdrive/My\ Drive/KKB-kaggle/bengaliai-cv19/notebooks
# Out:
# /content/gdrive/My Drive/KKB-kaggle/bengaliai-cv19/notebooks

# %%
# %pip install PIL
# Out:
# ERROR: Could not find a version that satisfies the requirement PIL (from versions: none)
# ERROR: No matching distribution found for PIL

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in 

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
from tqdm.auto import tqdm
from glob import glob
import time, gc
import cv2

from tensorflow import keras
import matplotlib.image as mpimg
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Model
from keras.models import clone_model
from keras.layers import Dense,Conv2D,Flatten,MaxPool2D,Dropout,BatchNormalization, Input
from keras.optimizers import Adam
from keras.callbacks import ReduceLROnPlateau
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
import PIL.Image as Image, PIL.ImageDraw as ImageDraw, PIL.ImageFont as ImageFont
from matplotlib import pyplot as plt
import seaborn as sns

# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('../dataset/'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# Any results you write to the current directory are saved as output.

dataset_dir = '../dataset'
# Out:
# <p style="color: red;">
# The default version of TensorFlow in Colab will soon switch to TensorFlow 2.x.<br>
# We recommend you <a href="https://www.tensorflow.org/guide/migrate" target="_blank">upgrade</a> now
# or ensure your notebook will continue to use TensorFlow 1.x via the <code>%tensorflow_version 1.x</code> magic:
# <a href="https://colab.research.google.com/notebooks/tensorflow_version.ipynb" target="_blank">more info</a>.</p>
# Using TensorFlow backend.
# ../dataset/class_map.csv
# ../dataset/sample_submission.csv
# ../dataset/test_image_data_0.parquet
# ../dataset/test_image_data_2.parquet
# ../dataset/test_image_data_3.parquet
# ../dataset/test.csv
# ../dataset/train_image_data_0.parquet
# ../dataset/train_image_data_1.parquet
# ../dataset/train_image_data_2.parquet
# ../dataset/train_image_data_3.parquet
# ../dataset/train.csv

# %%
train_df_ = pd.read_csv(dataset_dir + '/train.csv')
test_df_ = pd.read_csv(dataset_dir + '/test.csv')
class_map_df = pd.read_csv(dataset_dir + '/class_map.csv')
sample_sub_df = pd.read_csv(dataset_dir + '/sample_submission.csv')

# %%
train_df_.head()
# Out:
#   image_id  grapheme_root  vowel_diacritic  consonant_diacritic grapheme
# 0  Train_0             15                9                    5   ক্ট্রো
# 1  Train_1            159                0                    0        হ
# 2  Train_2             22                3                    5     খ্রী
# 3  Train_3             53                2                    2     র্টি
# 4  Train_4             71                9                    5     থ্রো

# %%
test_df_.head()
# Out:
#                        row_id image_id            component
# 0  Test_0_consonant_diacritic   Test_0  consonant_diacritic
# 1        Test_0_grapheme_root   Test_0        grapheme_root
# 2      Test_0_vowel_diacritic   Test_0      vowel_diacritic
# 3  Test_1_consonant_diacritic   Test_1  consonant_diacritic
# 4        Test_1_grapheme_root   Test_1        grapheme_root

# %%
sample_sub_df.head()
# Out:
#                        row_id  target
# 0  Test_0_consonant_diacritic       0
# 1        Test_0_grapheme_root       0
# 2      Test_0_vowel_diacritic       0
# 3  Test_1_consonant_diacritic       0
# 4        Test_1_grapheme_root       0

# %%
class_map_df.head()
# Out:
#   component_type  label component
# 0  grapheme_root      0         ং
# 1  grapheme_root      1         ঃ
# 2  grapheme_root      2         অ
# 3  grapheme_root      3         আ
# 4  grapheme_root      4         ই

# %%
print(f'Size of training data: {train_df_.shape}')
print(f'Size of test data: {test_df_.shape}')
print(f'Size of class map: {class_map_df.shape}')
# Out:
# Size of training data: (200840, 5)
# Size of test data: (36, 3)
# Size of class map: (186, 3)

# %% [markdown]
# ## Exploratory Data Analysis
# Exploratory data analysis (EDA) is an approach to analyzing data sets to summarize their main characteristics, often with visual methods.

# %%
HEIGHT = 236
WIDTH = 236

def get_n(df, field, n, top=True):
    top_graphemes = df.groupby([field]).size().reset_index(name='counts')['counts'].sort_values(ascending=not top)[:n]
    top_grapheme_roots = top_graphemes.index
    top_grapheme_counts = top_graphemes.values
    top_graphemes = class_map_df[class_map_df['component_type'] == field].reset_index().iloc[top_grapheme_roots]
    top_graphemes.drop(['component_type', 'label'], axis=1, inplace=True)
    top_graphemes.loc[:, 'count'] = top_grapheme_counts
    return top_graphemes

def image_from_char(char):
    image = Image.new('RGB', (WIDTH, HEIGHT))
    draw = ImageDraw.Draw(image)
    myfont = ImageFont.truetype(dataset_dir + '/kalpurush-fonts/kalpurush-2.ttf', 120)
    w, h = draw.textsize(char, font=myfont)
    draw.text(((WIDTH - w) / 2,(HEIGHT - h) / 3), char, font=myfont)

    return image

# %% [markdown]
# ### Number of unique values

# %%
print(f'Number of unique grapheme roots: {train_df_["grapheme_root"].nunique()}')
print(f'Number of unique vowel diacritic: {train_df_["vowel_diacritic"].nunique()}')
print(f'Number of unique consonant diacritic: {train_df_["consonant_diacritic"].nunique()}')
# Out:
# Number of unique grapheme roots: 168
# Number of unique vowel diacritic: 11
# Number of unique consonant diacritic: 7

# %% [markdown]
# ### Most used top 10 Grapheme Roots in training set

# %%
top_10_roots = get_n(train_df_, 'grapheme_root', 10)
top_10_roots
# Out:
#      index component  count
# 72      72         দ   5736
# 64      64         ত   5596
# 13      13         ক   5420
# 107    107         ব   5321
# 23      23         গ   5149
# 96      96         প   4926
# 113    113         ভ   4395
# 147    147         স   4392
# 133    133         শ   4374
# 115    115         ম   4015

# %%
f, ax = plt.subplots(2, 5, figsize=(16, 8))
ax = ax.flatten()

for i in range(10):
    ax[i].imshow(image_from_char(top_10_roots['component'].iloc[i]), cmap='Greys')
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-13-32786fbc20fa> in <module>()
#       3
#       4 for i in range(10):
# ----> 5     ax[i].imshow(image_from_char(top_10_roots['component'].iloc[i]), cmap='Greys')
#
# <ipython-input-10-7b4a587ed9d8> in image_from_char(char)
#      14     image = Image.new('RGB', (WIDTH, HEIGHT))
#      15     draw = ImageDraw.Draw(image)
# ---> 16     myfont = ImageFont.truetype(dataset_dir + '/kalpurush-fonts/kalpurush-2.ttf', 120)
#      17     w, h = draw.textsize(char, font=myfont)
#      18     draw.text(((WIDTH - w) / 2,(HEIGHT - h) / 3), char, font=myfont)
#
# /usr/local/lib/python3.6/dist-packages/PIL/ImageFont.py in truetype(font, size, index, encoding, layout_engine)
#     638
#     639     try:
# --> 640         return freetype(font)
#     641     except IOError:
#     642         if not isPath(font):
#
# /usr/local/lib/python3.6/dist-packages/PIL/ImageFont.py in freetype(font)
#     635
#     636     def freetype(font):
# --> 637         return FreeTypeFont(font, size, index, encoding, layout_engine)
#     638
#     639     try:
#
# /usr/local/lib/python3.6/dist-packages/PIL/ImageFont.py in __init__(self, font, size, index, encoding, layout_engine)
#     184                     return
#     185             self.font = core.getfont(
# --> 186                 font, size, index, encoding, layout_engine=layout_engine
#     187             )
#     188         else:
#
# OSError: cannot open resource

# %% [markdown]
# ### Least used 10 Grapheme Roots in training set

# %%
bottom_10_roots = get_n(train_df_, 'grapheme_root', 10, False)
bottom_10_roots
# Out:
#      index component  count
# 73      73       দ্ঘ    130
# 33      33     ঙ্ক্ত    136
# 102    102       প্স    141
# 158    158       স্স    143
# 45      45     জ্জ্ব    144
# 130    130       ল্ব    144
# 1        1         ঃ    145
# 12      12         ঔ    146
# 0        0         ং    147
# 63      63       ণ্ণ    149

# %%
f, ax = plt.subplots(2, 5, figsize=(16, 8))
ax = ax.flatten()

for i in range(10):
    ax[i].imshow(image_from_char(bottom_10_roots['component'].iloc[i]), cmap='Greys')
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-18-244edc4b4209> in <module>()
#       3
#       4 for i in range(10):
# ----> 5     ax[i].imshow(image_from_char(bottom_10_roots['component'].iloc[i]), cmap='Greys')
#
# <ipython-input-10-7b4a587ed9d8> in image_from_char(char)
#      14     image = Image.new('RGB', (WIDTH, HEIGHT))
#      15     draw = ImageDraw.Draw(image)
# ---> 16     myfont = ImageFont.truetype(dataset_dir + '/kalpurush-fonts/kalpurush-2.ttf', 120)
#      17     w, h = draw.textsize(char, font=myfont)
#      18     draw.text(((WIDTH - w) / 2,(HEIGHT - h) / 3), char, font=myfont)
#
# /usr/local/lib/python3.6/dist-packages/PIL/ImageFont.py in truetype(font, size, index, encoding, layout_engine)
#     638
#     639     try:
# --> 640         return freetype(font)
#     641     except IOError:
#     642         if not isPath(font):
#
# /usr/local/lib/python3.6/dist-packages/PIL/ImageFont.py in freetype(font)
#     635
#     636     def freetype(font):
# --> 637         return FreeTypeFont(font, size, index, encoding, layout_engine)
#     638
#     639     try:
#
# /usr/local/lib/python3.6/dist-packages/PIL/ImageFont.py in __init__(self, font, size, index, encoding, layout_engine)
#     184                     return
#     185             self.font = core.getfont(
# --> 186                 font, size, index, encoding, layout_engine=layout_engine
#     187             )
#     188         else:
#
# OSError: cannot open resource

# %% [markdown]
# ### Top 5 Vowel Diacritic in taining data

# %%
top_5_vowels = get_n(train_df_, 'vowel_diacritic', 5)
top_5_vowels
# Out:
#    index component  count
# 0    168         0  41508
# 1    169         া  36886
# 7    175         ে  28723
# 2    170         ি  25967
# 4    172         ু  18848

# %%
f, ax = plt.subplots(1, 5, figsize=(16, 8))
ax = ax.flatten()

for i in range(5):
    ax[i].imshow(image_from_char(top_5_vowels['component'].iloc[i]), cmap='Greys')
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-20-ac879fabb100> in <module>()
#       3
#       4 for i in range(5):
# ----> 5     ax[i].imshow(image_from_char(top_5_vowels['component'].iloc[i]), cmap='Greys')
#
# <ipython-input-10-7b4a587ed9d8> in image_from_char(char)
#      14     image = Image.new('RGB', (WIDTH, HEIGHT))
#      15     draw = ImageDraw.Draw(image)
# ---> 16     myfont = ImageFont.truetype(dataset_dir + '/kalpurush-fonts/kalpurush-2.ttf', 120)
#      17     w, h = draw.textsize(char, font=myfont)
#      18     draw.text(((WIDTH - w) / 2,(HEIGHT - h) / 3), char, font=myfont)
#
# /usr/local/lib/python3.6/dist-packages/PIL/ImageFont.py in truetype(font, size, index, encoding, layout_engine)
#     638
#     639     try:
# --> 640         return freetype(font)
#     641     except IOError:
#     642         if not isPath(font):
#
# /usr/local/lib/python3.6/dist-packages/PIL/ImageFont.py in freetype(font)
#     635
#     636     def freetype(font):
# --> 637         return FreeTypeFont(font, size, index, encoding, layout_engine)
#     638
#     639     try:
#
# /usr/local/lib/python3.6/dist-packages/PIL/ImageFont.py in __init__(self, font, size, index, encoding, layout_engine)
#     184                     return
#     185             self.font = core.getfont(
# --> 186                 font, size, index, encoding, layout_engine=layout_engine
#     187             )
#     188         else:
#
# OSError: cannot open resource

# %% [markdown]
# ### Top 5 Consonant Diacritic in training data

# %%
top_5_consonants = get_n(train_df_, 'consonant_diacritic', 5)
top_5_consonants
# Out:
#    index component   count
# 0    179         0  125278
# 2    181        র্   23465
# 5    184        ্র   21397
# 4    183        ্য   21270
# 1    180         ঁ    7424

# %%
f, ax = plt.subplots(1, 5, figsize=(16, 8))
ax = ax.flatten()

for i in range(5):
    ax[i].imshow(image_from_char(top_5_consonants['component'].iloc[i]), cmap='Greys')

# %%
train_df_ = train_df_.drop(['grapheme'], axis=1, inplace=False)

# %%
train_df_[['grapheme_root', 'vowel_diacritic', 'consonant_diacritic']] = train_df_[['grapheme_root', 'vowel_diacritic', 'consonant_diacritic']].astype('uint8')

# %%
IMG_SIZE=64
N_CHANNELS=1

# %% [markdown]
# Let's apply some image processing (credits: [this kernel](https://www.kaggle.com/shawon10/bangla-graphemes-image-processing-deep-cnn)) while resizing the images, which will center crop the region of interest from the original images.

# %%
def resize(df, size=64, need_progress_bar=True):
    resized = {}
    resize_size=64
    if need_progress_bar:
        for i in tqdm(range(df.shape[0])):
            image=df.loc[df.index[i]].values.reshape(137,236)
            _, thresh = cv2.threshold(image, 30, 255, cv2.THRESH_BINARY_INV + cv2.THRESH_OTSU)
            contours, _ = cv2.findContours(thresh,cv2.RETR_LIST,cv2.CHAIN_APPROX_SIMPLE)[-2:]

            idx = 0 
            ls_xmin = []
            ls_ymin = []
            ls_xmax = []
            ls_ymax = []
            for cnt in contours:
                idx += 1
                x,y,w,h = cv2.boundingRect(cnt)
                ls_xmin.append(x)
                ls_ymin.append(y)
                ls_xmax.append(x + w)
                ls_ymax.append(y + h)
            xmin = min(ls_xmin)
            ymin = min(ls_ymin)
            xmax = max(ls_xmax)
            ymax = max(ls_ymax)

            roi = image[ymin:ymax,xmin:xmax]
            resized_roi = cv2.resize(roi, (resize_size, resize_size),interpolation=cv2.INTER_AREA)
            resized[df.index[i]] = resized_roi.reshape(-1)
    else:
        for i in range(df.shape[0]):
            #image = cv2.resize(df.loc[df.index[i]].values.reshape(137,236),(size,size),None,fx=0.5,fy=0.5,interpolation=cv2.INTER_AREA)
            image=df.loc[df.index[i]].values.reshape(137,236)
            _, thresh = cv2.threshold(image, 30, 255, cv2.THRESH_BINARY_INV + cv2.THRESH_OTSU)
            contours, _ = cv2.findContours(thresh,cv2.RETR_LIST,cv2.CHAIN_APPROX_SIMPLE)[-2:]

            idx = 0 
            ls_xmin = []
            ls_ymin = []
            ls_xmax = []
            ls_ymax = []
            for cnt in contours:
                idx += 1
                x,y,w,h = cv2.boundingRect(cnt)
                ls_xmin.append(x)
                ls_ymin.append(y)
                ls_xmax.append(x + w)
                ls_ymax.append(y + h)
            xmin = min(ls_xmin)
            ymin = min(ls_ymin)
            xmax = max(ls_xmax)
            ymax = max(ls_ymax)

            roi = image[ymin:ymax,xmin:xmax]
            resized_roi = cv2.resize(roi, (resize_size, resize_size),interpolation=cv2.INTER_AREA)
            resized[df.index[i]] = resized_roi.reshape(-1)
    resized = pd.DataFrame(resized).T
    return resized

# %%
def get_dummies(df):
    cols = []
    for col in df:
        cols.append(pd.get_dummies(df[col].astype(str)))
    return pd.concat(cols, axis=1)

# %% [markdown]
# ## Basic Model

# %%
inputs = Input(shape = (IMG_SIZE, IMG_SIZE, 1))

model = Conv2D(filters=32, kernel_size=(3, 3), padding='SAME', activation='relu', input_shape=(IMG_SIZE, IMG_SIZE, 1))(inputs)
model = Conv2D(filters=32, kernel_size=(3, 3), padding='SAME', activation='relu')(model)
model = Conv2D(filters=32, kernel_size=(3, 3), padding='SAME', activation='relu')(model)
model = Conv2D(filters=32, kernel_size=(3, 3), padding='SAME', activation='relu')(model)
model = BatchNormalization(momentum=0.15)(model)
model = MaxPool2D(pool_size=(2, 2))(model)
model = Conv2D(filters=32, kernel_size=(5, 5), padding='SAME', activation='relu')(model)
model = Dropout(rate=0.3)(model)

model = Conv2D(filters=64, kernel_size=(3, 3), padding='SAME', activation='relu')(model)
model = Conv2D(filters=64, kernel_size=(3, 3), padding='SAME', activation='relu')(model)
model = Conv2D(filters=64, kernel_size=(3, 3), padding='SAME', activation='relu')(model)
model = Conv2D(filters=64, kernel_size=(3, 3), padding='SAME', activation='relu')(model)
model = BatchNormalization(momentum=0.15)(model)
model = MaxPool2D(pool_size=(2, 2))(model)
model = Conv2D(filters=64, kernel_size=(5, 5), padding='SAME', activation='relu')(model)
model = BatchNormalization(momentum=0.15)(model)
model = Dropout(rate=0.3)(model)

model = Conv2D(filters=128, kernel_size=(3, 3), padding='SAME', activation='relu')(model)
model = Conv2D(filters=128, kernel_size=(3, 3), padding='SAME', activation='relu')(model)
model = Conv2D(filters=128, kernel_size=(3, 3), padding='SAME', activation='relu')(model)
model = Conv2D(filters=128, kernel_size=(3, 3), padding='SAME', activation='relu')(model)
model = BatchNormalization(momentum=0.15)(model)
model = MaxPool2D(pool_size=(2, 2))(model)
model = Conv2D(filters=128, kernel_size=(5, 5), padding='SAME', activation='relu')(model)
model = BatchNormalization(momentum=0.15)(model)
model = Dropout(rate=0.3)(model)

model = Conv2D(filters=256, kernel_size=(3, 3), padding='SAME', activation='relu')(model)
model = Conv2D(filters=256, kernel_size=(3, 3), padding='SAME', activation='relu')(model)
model = Conv2D(filters=256, kernel_size=(3, 3), padding='SAME', activation='relu')(model)
model = Conv2D(filters=256, kernel_size=(3, 3), padding='SAME', activation='relu')(model)
model = BatchNormalization(momentum=0.15)(model)
model = MaxPool2D(pool_size=(2, 2))(model)
model = Conv2D(filters=256, kernel_size=(5, 5), padding='SAME', activation='relu')(model)
model = BatchNormalization(momentum=0.15)(model)
model = Dropout(rate=0.3)(model)

model = Flatten()(model)
model = Dense(1024, activation = "relu")(model)
model = Dropout(rate=0.3)(model)
dense = Dense(512, activation = "relu")(model)

head_root = Dense(168, activation = 'softmax')(dense)
head_vowel = Dense(11, activation = 'softmax')(dense)
head_consonant = Dense(7, activation = 'softmax')(dense)

model = Model(inputs=inputs, outputs=[head_root, head_vowel, head_consonant])

# %%
model.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 64, 64, 1)    0
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 64, 64, 32)   320         input_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 64, 64, 32)   9248        conv2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 64, 64, 32)   9248        conv2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 64, 64, 32)   9248        conv2d_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 64, 64, 32)   128         conv2d_4[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 32, 32, 32)   0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 32, 32, 32)   25632       max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 32, 32, 32)   0           conv2d_5[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 32, 32, 64)   18496       dropout_1[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 32, 32, 64)   36928       conv2d_6[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 32, 32, 64)   36928       conv2d_7[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 32, 32, 64)   36928       conv2d_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 32, 32, 64)   256         conv2d_9[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 16, 16, 64)   0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 16, 16, 64)   102464      max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 16, 16, 64)   256         conv2d_10[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 16, 16, 64)   0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 16, 16, 128)  73856       dropout_2[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 16, 16, 128)  147584      conv2d_11[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 16, 16, 128)  147584      conv2d_12[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 16, 16, 128)  147584      conv2d_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 16, 16, 128)  512         conv2d_14[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 8, 8, 128)    0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 8, 8, 128)    409728      max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 8, 8, 128)    512         conv2d_15[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 8, 8, 128)    0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 8, 8, 256)    295168      dropout_3[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 8, 8, 256)    590080      conv2d_16[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 8, 8, 256)    590080      conv2d_17[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 8, 8, 256)    590080      conv2d_18[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 8, 8, 256)    1024        conv2d_19[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_4 (MaxPooling2D)  (None, 4, 4, 256)    0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 4, 4, 256)    1638656     max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 4, 4, 256)    1024        conv2d_20[0][0]
# __________________________________________________________________________________________________
# dropout_4 (Dropout)             (None, 4, 4, 256)    0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 4096)         0           dropout_4[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 1024)         4195328     flatten_1[0][0]
# __________________________________________________________________________________________________
# dropout_5 (Dropout)             (None, 1024)         0           dense_1[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 512)          524800      dropout_5[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 168)          86184       dense_2[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 11)           5643        dense_2[0][0]
# __________________________________________________________________________________________________
# dense_5 (Dense)                 (None, 7)            3591        dense_2[0][0]
# ==================================================================================================
# Total params: 9,735,098
# Trainable params: 9,733,242
# Non-trainable params: 1,856
# __________________________________________________________________________________________________

# %% [markdown]
# Let's visualize the 3-tailed (3 output) CNN by plotting it.

# %%
from keras.utils import plot_model
plot_model(model, to_file='model.png')

# %%
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/optimizers.py:793: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3576: The name tf.log is deprecated. Please use tf.math.log instead.

# %%
# Set a learning rate annealer. Learning rate will be half after 3 epochs if accuracy is not increased
learning_rate_reduction_root = ReduceLROnPlateau(monitor='dense_3_accuracy', 
                                            patience=3, 
                                            verbose=1,
                                            factor=0.5, 
                                            min_lr=0.00001)
learning_rate_reduction_vowel = ReduceLROnPlateau(monitor='dense_4_accuracy', 
                                            patience=3, 
                                            verbose=1,
                                            factor=0.5, 
                                            min_lr=0.00001)
learning_rate_reduction_consonant = ReduceLROnPlateau(monitor='dense_5_accuracy', 
                                            patience=3, 
                                            verbose=1,
                                            factor=0.5, 
                                            min_lr=0.00001)

# %%
batch_size = 256
epochs = 30

# %%
class MultiOutputDataGenerator(keras.preprocessing.image.ImageDataGenerator):

    def flow(self,
             x,
             y=None,
             batch_size=32,
             shuffle=True,
             sample_weight=None,
             seed=None,
             save_to_dir=None,
             save_prefix='',
             save_format='png',
             subset=None):

        targets = None
        target_lengths = {}
        ordered_outputs = []
        for output, target in y.items():
            if targets is None:
                targets = target
            else:
                targets = np.concatenate((targets, target), axis=1)
            target_lengths[output] = target.shape[1]
            ordered_outputs.append(output)


        for flowx, flowy in super().flow(x, targets, batch_size=batch_size,
                                         shuffle=shuffle):
            target_dict = {}
            i = 0
            for output in ordered_outputs:
                target_length = target_lengths[output]
                target_dict[output] = flowy[:, i: i + target_length]
                i += target_length

            yield flowx, target_dict

# %%
HEIGHT = 137
WIDTH = 236

# %% [markdown]
# ### Training loop

# %%
histories = []
for i in range(4):
    train_df = pd.merge(pd.read_parquet(dataset_dir + '/train_image_data_{}.parquet'.format(i)), train_df_, on='image_id').drop(['image_id'], axis=1)
    
    # Visualize few samples of current training dataset
    fig, ax = plt.subplots(nrows=3, ncols=4, figsize=(16, 8))
    count=0
    for row in ax:
        for col in row:
            col.imshow(resize(train_df.drop(['grapheme_root', 'vowel_diacritic', 'consonant_diacritic'], axis=1).iloc[[count]], need_progress_bar=False).values.reshape(-1).reshape(IMG_SIZE, IMG_SIZE).astype(np.float64))
            count += 1
    plt.show()
    
    X_train = train_df.drop(['grapheme_root', 'vowel_diacritic', 'consonant_diacritic'], axis=1)
    X_train = resize(X_train)/255
    
    # CNN takes images in shape `(batch_size, h, w, channels)`, so reshape the images
    X_train = X_train.values.reshape(-1, IMG_SIZE, IMG_SIZE, N_CHANNELS)
    
    Y_train_root = pd.get_dummies(train_df['grapheme_root']).values
    Y_train_vowel = pd.get_dummies(train_df['vowel_diacritic']).values
    Y_train_consonant = pd.get_dummies(train_df['consonant_diacritic']).values

    print(f'Training images: {X_train.shape}')
    print(f'Training labels root: {Y_train_root.shape}')
    print(f'Training labels vowel: {Y_train_vowel.shape}')
    print(f'Training labels consonants: {Y_train_consonant.shape}')

    # Divide the data into training and validation set
    x_train, x_test, y_train_root, y_test_root, y_train_vowel, y_test_vowel, y_train_consonant, y_test_consonant = train_test_split(X_train, Y_train_root, Y_train_vowel, Y_train_consonant, test_size=0.08, random_state=666)
    del train_df
    del X_train
    del Y_train_root, Y_train_vowel, Y_train_consonant

    # Data augmentation for creating more training data
    datagen = MultiOutputDataGenerator(
        featurewise_center=False,  # set input mean to 0 over the dataset
        samplewise_center=False,  # set each sample mean to 0
        featurewise_std_normalization=False,  # divide inputs by std of the dataset
        samplewise_std_normalization=False,  # divide each input by its std
        zca_whitening=False,  # apply ZCA whitening
        rotation_range=8,  # randomly rotate images in the range (degrees, 0 to 180)
        zoom_range = 0.15, # Randomly zoom image 
        width_shift_range=0.15,  # randomly shift images horizontally (fraction of total width)
        height_shift_range=0.15,  # randomly shift images vertically (fraction of total height)
        horizontal_flip=False,  # randomly flip images
        vertical_flip=False)  # randomly flip images


    # This will just calculate parameters required to augment the given data. This won't perform any augmentations
    datagen.fit(x_train)

    # Fit the model
    history = model.fit_generator(datagen.flow(x_train, {'dense_3': y_train_root, 'dense_4': y_train_vowel, 'dense_5': y_train_consonant}, batch_size=batch_size),
                              epochs = epochs, validation_data = (x_test, [y_test_root, y_test_vowel, y_test_consonant]), 
                              steps_per_epoch=x_train.shape[0] // batch_size, 
                              callbacks=[learning_rate_reduction_root, learning_rate_reduction_vowel, learning_rate_reduction_consonant])

    histories.append(history)
    
    # Delete to reduce memory usage
    del x_train
    del x_test
    del y_train_root
    del y_test_root
    del y_train_vowel
    del y_test_vowel
    del y_train_consonant
    del y_test_consonant
    gc.collect()
# Out:
# HBox(children=(IntProgress(value=0, max=50210), HTML(value='')))
# Training images: (50210, 64, 64, 1)
# Training labels root: (50210, 168)
# Training labels vowel: (50210, 11)
# Training labels consonants: (50210, 7)
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/math_grad.py:1424: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1033: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1020: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
#
# Epoch 1/30
# 180/180 [==============================] - 64s 356ms/step - loss: 7.7442 - dense_3_loss: 4.7464 - dense_4_loss: 1.8332 - dense_5_loss: 1.1646 - dense_3_acc: 0.0311 - dense_4_acc: 0.3542 - dense_5_acc: 0.6261 - val_loss: 6.7303 - val_dense_3_loss: 4.5470 - val_dense_4_loss: 1.1884 - val_dense_5_loss: 0.9950 - val_dense_3_acc: 0.0344 - val_dense_4_acc: 0.5768 - val_dense_5_acc: 0.6388
# Epoch 2/30
# /usr/local/lib/python3.6/dist-packages/keras/callbacks.py:1379: RuntimeWarning: Reduce LR on plateau conditioned on metric `dense_3_accuracy` which is not available. Available metrics are: val_loss,val_dense_3_loss,val_dense_4_loss,val_dense_5_loss,val_dense_3_acc,val_dense_4_acc,val_dense_5_acc,loss,dense_3_loss,dense_4_loss,dense_5_loss,dense_3_acc,dense_4_acc,dense_5_acc,lr
#   (self.monitor, ','.join(list(logs.keys()))), RuntimeWarning
# /usr/local/lib/python3.6/dist-packages/keras/callbacks.py:1379: RuntimeWarning: Reduce LR on plateau conditioned on metric `dense_4_accuracy` which is not available. Available metrics are: val_loss,val_dense_3_loss,val_dense_4_loss,val_dense_5_loss,val_dense_3_acc,val_dense_4_acc,val_dense_5_acc,loss,dense_3_loss,dense_4_loss,dense_5_loss,dense_3_acc,dense_4_acc,dense_5_acc,lr
#   (self.monitor, ','.join(list(logs.keys()))), RuntimeWarning
# /usr/local/lib/python3.6/dist-packages/keras/callbacks.py:1379: RuntimeWarning: Reduce LR on plateau conditioned on metric `dense_5_accuracy` which is not available. Available metrics are: val_loss,val_dense_3_loss,val_dense_4_loss,val_dense_5_loss,val_dense_3_acc,val_dense_4_acc,val_dense_5_acc,loss,dense_3_loss,dense_4_loss,dense_5_loss,dense_3_acc,dense_4_acc,dense_5_acc,lr
#   (self.monitor, ','.join(list(logs.keys()))), RuntimeWarning
# 180/180 [==============================] - 52s 289ms/step - loss: 6.7226 - dense_3_loss: 4.4827 - dense_4_loss: 1.2728 - dense_5_loss: 0.9671 - dense_3_acc: 0.0416 - dense_4_acc: 0.5631 - dense_5_acc: 0.6693 - val_loss: 6.1434 - val_dense_3_loss: 4.3331 - val_dense_4_loss: 0.9258 - val_dense_5_loss: 0.8844 - val_dense_3_acc: 0.0478 - val_dense_4_acc: 0.6761 - val_dense_5_acc: 0.6833
# Epoch 3/30
# 180/180 [==============================] - 51s 285ms/step - loss: 6.1697 - dense_3_loss: 4.2076 - dense_4_loss: 1.1038 - dense_5_loss: 0.8583 - dense_3_acc: 0.0659 - dense_4_acc: 0.6221 - dense_5_acc: 0.7043 - val_loss: 6.1227 - val_dense_3_loss: 4.1456 - val_dense_4_loss: 1.1297 - val_dense_5_loss: 0.8474 - val_dense_3_acc: 0.0727 - val_dense_4_acc: 0.5940 - val_dense_5_acc: 0.7062
# Epoch 4/30
# 180/180 [==============================] - 52s 288ms/step - loss: 5.4371 - dense_3_loss: 3.7512 - dense_4_loss: 0.9460 - dense_5_loss: 0.7398 - dense_3_acc: 0.1120 - dense_4_acc: 0.6821 - dense_5_acc: 0.7399 - val_loss: 4.1983 - val_dense_3_loss: 3.1050 - val_dense_4_loss: 0.5460 - val_dense_5_loss: 0.5473 - val_dense_3_acc: 0.1932 - val_dense_4_acc: 0.8220 - val_dense_5_acc: 0.8028
# Epoch 5/30
# 180/180 [==============================] - 52s 290ms/step - loss: 4.4331 - dense_3_loss: 3.0651 - dense_4_loss: 0.7673 - dense_5_loss: 0.6007 - dense_3_acc: 0.2138 - dense_4_acc: 0.7477 - dense_5_acc: 0.7929 - val_loss: 3.0756 - val_dense_3_loss: 2.2931 - val_dense_4_loss: 0.3936 - val_dense_5_loss: 0.3888 - val_dense_3_acc: 0.3555 - val_dense_4_acc: 0.8676 - val_dense_5_acc: 0.8673
# Epoch 6/30
# 180/180 [==============================] - 52s 291ms/step - loss: 3.5675 - dense_3_loss: 2.4369 - dense_4_loss: 0.6480 - dense_5_loss: 0.4827 - dense_3_acc: 0.3303 - dense_4_acc: 0.7876 - dense_5_acc: 0.8369 - val_loss: 2.3405 - val_dense_3_loss: 1.6914 - val_dense_4_loss: 0.3127 - val_dense_5_loss: 0.3364 - val_dense_3_acc: 0.4946 - val_dense_4_acc: 0.9049 - val_dense_5_acc: 0.8815
# Epoch 7/30
# 180/180 [==============================] - 53s 293ms/step - loss: 3.1515 - dense_3_loss: 2.0906 - dense_4_loss: 0.6204 - dense_5_loss: 0.4405 - dense_3_acc: 0.4204 - dense_4_acc: 0.7994 - dense_5_acc: 0.8551 - val_loss: 1.8786 - val_dense_3_loss: 1.3689 - val_dense_4_loss: 0.2617 - val_dense_5_loss: 0.2481 - val_dense_3_acc: 0.5863 - val_dense_4_acc: 0.9208 - val_dense_5_acc: 0.9131
# Epoch 8/30
# 180/180 [==============================] - 53s 293ms/step - loss: 2.5219 - dense_3_loss: 1.6408 - dense_4_loss: 0.5152 - dense_5_loss: 0.3659 - dense_3_acc: 0.5339 - dense_4_acc: 0.8360 - dense_5_acc: 0.8808 - val_loss: 1.5765 - val_dense_3_loss: 1.1012 - val_dense_4_loss: 0.2448 - val_dense_5_loss: 0.2304 - val_dense_3_acc: 0.6734 - val_dense_4_acc: 0.9238 - val_dense_5_acc: 0.9273
# Epoch 9/30
# 180/180 [==============================] - 53s 294ms/step - loss: 2.5145 - dense_3_loss: 1.6119 - dense_4_loss: 0.5250 - dense_5_loss: 0.3776 - dense_3_acc: 0.5532 - dense_4_acc: 0.8338 - dense_5_acc: 0.8768 - val_loss: 1.5309 - val_dense_3_loss: 1.0161 - val_dense_4_loss: 0.2538 - val_dense_5_loss: 0.2611 - val_dense_3_acc: 0.7080 - val_dense_4_acc: 0.9246 - val_dense_5_acc: 0.9208
# Epoch 10/30
# 180/180 [==============================] - 53s 294ms/step - loss: 2.1267 - dense_3_loss: 1.3506 - dense_4_loss: 0.4513 - dense_5_loss: 0.3248 - dense_3_acc: 0.6212 - dense_4_acc: 0.8570 - dense_5_acc: 0.8947 - val_loss: 1.5215 - val_dense_3_loss: 0.9752 - val_dense_4_loss: 0.3247 - val_dense_5_loss: 0.2215 - val_dense_3_acc: 0.7346 - val_dense_4_acc: 0.9206 - val_dense_5_acc: 0.9390
# Epoch 11/30
# 180/180 [==============================] - 53s 294ms/step - loss: 2.3179 - dense_3_loss: 1.4458 - dense_4_loss: 0.4983 - dense_5_loss: 0.3737 - dense_3_acc: 0.6007 - dense_4_acc: 0.8414 - dense_5_acc: 0.8788 - val_loss: 1.2918 - val_dense_3_loss: 0.8647 - val_dense_4_loss: 0.2285 - val_dense_5_loss: 0.1986 - val_dense_3_acc: 0.7473 - val_dense_4_acc: 0.9335 - val_dense_5_acc: 0.9373
# Epoch 12/30
# 180/180 [==============================] - 53s 294ms/step - loss: 2.3863 - dense_3_loss: 1.5082 - dense_4_loss: 0.5116 - dense_5_loss: 0.3665 - dense_3_acc: 0.5894 - dense_4_acc: 0.8380 - dense_5_acc: 0.8795 - val_loss: 1.3236 - val_dense_3_loss: 0.9112 - val_dense_4_loss: 0.2323 - val_dense_5_loss: 0.1801 - val_dense_3_acc: 0.7314 - val_dense_4_acc: 0.9300 - val_dense_5_acc: 0.9420
# Epoch 13/30
# 180/180 [==============================] - 53s 293ms/step - loss: 1.9331 - dense_3_loss: 1.1961 - dense_4_loss: 0.4278 - dense_5_loss: 0.3091 - dense_3_acc: 0.6618 - dense_4_acc: 0.8659 - dense_5_acc: 0.8981 - val_loss: 1.1199 - val_dense_3_loss: 0.7344 - val_dense_4_loss: 0.2204 - val_dense_5_loss: 0.1651 - val_dense_3_acc: 0.7832 - val_dense_4_acc: 0.9353 - val_dense_5_acc: 0.9487
# Epoch 14/30
# 180/180 [==============================] - 53s 293ms/step - loss: 1.8143 - dense_3_loss: 1.1103 - dense_4_loss: 0.4107 - dense_5_loss: 0.2933 - dense_3_acc: 0.6912 - dense_4_acc: 0.8705 - dense_5_acc: 0.9052 - val_loss: 1.2663 - val_dense_3_loss: 0.8514 - val_dense_4_loss: 0.2073 - val_dense_5_loss: 0.2076 - val_dense_3_acc: 0.7486 - val_dense_4_acc: 0.9403 - val_dense_5_acc: 0.9378
# Epoch 15/30
# 180/180 [==============================] - 53s 293ms/step - loss: 1.5934 - dense_3_loss: 0.9660 - dense_4_loss: 0.3614 - dense_5_loss: 0.2660 - dense_3_acc: 0.7252 - dense_4_acc: 0.8881 - dense_5_acc: 0.9139 - val_loss: 0.9276 - val_dense_3_loss: 0.6197 - val_dense_4_loss: 0.1760 - val_dense_5_loss: 0.1320 - val_dense_3_acc: 0.8170 - val_dense_4_acc: 0.9507 - val_dense_5_acc: 0.9582
# Epoch 16/30
# 180/180 [==============================] - 53s 293ms/step - loss: 1.4354 - dense_3_loss: 0.8578 - dense_4_loss: 0.3360 - dense_5_loss: 0.2416 - dense_3_acc: 0.7556 - dense_4_acc: 0.8948 - dense_5_acc: 0.9230 - val_loss: 0.9895 - val_dense_3_loss: 0.6165 - val_dense_4_loss: 0.2094 - val_dense_5_loss: 0.1636 - val_dense_3_acc: 0.8215 - val_dense_4_acc: 0.9457 - val_dense_5_acc: 0.9460
# Epoch 17/30
# 180/180 [==============================] - 53s 293ms/step - loss: 1.3705 - dense_3_loss: 0.8204 - dense_4_loss: 0.3173 - dense_5_loss: 0.2329 - dense_3_acc: 0.7663 - dense_4_acc: 0.9015 - dense_5_acc: 0.9260 - val_loss: 0.8626 - val_dense_3_loss: 0.5767 - val_dense_4_loss: 0.1413 - val_dense_5_loss: 0.1446 - val_dense_3_acc: 0.8233 - val_dense_4_acc: 0.9604 - val_dense_5_acc: 0.9544
# Epoch 18/30
# 180/180 [==============================] - 53s 292ms/step - loss: 1.3412 - dense_3_loss: 0.7930 - dense_4_loss: 0.3162 - dense_5_loss: 0.2319 - dense_3_acc: 0.7750 - dense_4_acc: 0.9033 - dense_5_acc: 0.9259 - val_loss: 0.8496 - val_dense_3_loss: 0.5640 - val_dense_4_loss: 0.1424 - val_dense_5_loss: 0.1432 - val_dense_3_acc: 0.8362 - val_dense_4_acc: 0.9579 - val_dense_5_acc: 0.9529
# Epoch 19/30
# 180/180 [==============================] - 53s 292ms/step - loss: 1.2636 - dense_3_loss: 0.7487 - dense_4_loss: 0.3005 - dense_5_loss: 0.2143 - dense_3_acc: 0.7844 - dense_4_acc: 0.9080 - dense_5_acc: 0.9306 - val_loss: 0.8044 - val_dense_3_loss: 0.5177 - val_dense_4_loss: 0.1526 - val_dense_5_loss: 0.1341 - val_dense_3_acc: 0.8496 - val_dense_4_acc: 0.9587 - val_dense_5_acc: 0.9564
# Epoch 20/30
# 180/180 [==============================] - 53s 293ms/step - loss: 1.2616 - dense_3_loss: 0.7367 - dense_4_loss: 0.3044 - dense_5_loss: 0.2205 - dense_3_acc: 0.7898 - dense_4_acc: 0.9060 - dense_5_acc: 0.9297 - val_loss: 0.7969 - val_dense_3_loss: 0.5122 - val_dense_4_loss: 0.1486 - val_dense_5_loss: 0.1361 - val_dense_3_acc: 0.8474 - val_dense_4_acc: 0.9589 - val_dense_5_acc: 0.9584
# Epoch 21/30
# 180/180 [==============================] - 53s 293ms/step - loss: 1.3986 - dense_3_loss: 0.8118 - dense_4_loss: 0.3439 - dense_5_loss: 0.2429 - dense_3_acc: 0.7685 - dense_4_acc: 0.8933 - dense_5_acc: 0.9214 - val_loss: 0.7954 - val_dense_3_loss: 0.5204 - val_dense_4_loss: 0.1430 - val_dense_5_loss: 0.1320 - val_dense_3_acc: 0.8484 - val_dense_4_acc: 0.9594 - val_dense_5_acc: 0.9582
# Epoch 22/30
# 180/180 [==============================] - 53s 293ms/step - loss: 1.2605 - dense_3_loss: 0.7251 - dense_4_loss: 0.3092 - dense_5_loss: 0.2262 - dense_3_acc: 0.7933 - dense_4_acc: 0.9056 - dense_5_acc: 0.9273 - val_loss: 0.7045 - val_dense_3_loss: 0.4535 - val_dense_4_loss: 0.1300 - val_dense_5_loss: 0.1209 - val_dense_3_acc: 0.8656 - val_dense_4_acc: 0.9661 - val_dense_5_acc: 0.9607
# Epoch 23/30
# 180/180 [==============================] - 53s 293ms/step - loss: 1.0402 - dense_3_loss: 0.5958 - dense_4_loss: 0.2615 - dense_5_loss: 0.1829 - dense_3_acc: 0.8263 - dense_4_acc: 0.9203 - dense_5_acc: 0.9404 - val_loss: 0.7299 - val_dense_3_loss: 0.4542 - val_dense_4_loss: 0.1644 - val_dense_5_loss: 0.1113 - val_dense_3_acc: 0.8663 - val_dense_4_acc: 0.9572 - val_dense_5_acc: 0.9639
# Epoch 24/30
# 180/180 [==============================] - 53s 293ms/step - loss: 1.2912 - dense_3_loss: 0.7475 - dense_4_loss: 0.3204 - dense_5_loss: 0.2233 - dense_3_acc: 0.7902 - dense_4_acc: 0.9005 - dense_5_acc: 0.9288 - val_loss: 0.7548 - val_dense_3_loss: 0.4883 - val_dense_4_loss: 0.1479 - val_dense_5_loss: 0.1187 - val_dense_3_acc: 0.8656 - val_dense_4_acc: 0.9594 - val_dense_5_acc: 0.9642
# Epoch 25/30
# 180/180 [==============================] - 53s 294ms/step - loss: 1.2254 - dense_3_loss: 0.7049 - dense_4_loss: 0.3037 - dense_5_loss: 0.2168 - dense_3_acc: 0.7986 - dense_4_acc: 0.9075 - dense_5_acc: 0.9303 - val_loss: 0.7379 - val_dense_3_loss: 0.4643 - val_dense_4_loss: 0.1420 - val_dense_5_loss: 0.1317 - val_dense_3_acc: 0.8708 - val_dense_4_acc: 0.9624 - val_dense_5_acc: 0.9569
# Epoch 26/30
# 180/180 [==============================] - 53s 293ms/step - loss: 1.0654 - dense_3_loss: 0.6104 - dense_4_loss: 0.2665 - dense_5_loss: 0.1884 - dense_3_acc: 0.8224 - dense_4_acc: 0.9186 - dense_5_acc: 0.9396 - val_loss: 0.7062 - val_dense_3_loss: 0.4399 - val_dense_4_loss: 0.1533 - val_dense_5_loss: 0.1131 - val_dense_3_acc: 0.8750 - val_dense_4_acc: 0.9584 - val_dense_5_acc: 0.9649
# Epoch 27/30
# 180/180 [==============================] - 53s 293ms/step - loss: 1.0558 - dense_3_loss: 0.6001 - dense_4_loss: 0.2675 - dense_5_loss: 0.1881 - dense_3_acc: 0.8245 - dense_4_acc: 0.9193 - dense_5_acc: 0.9393 - val_loss: 0.7433 - val_dense_3_loss: 0.4590 - val_dense_4_loss: 0.1666 - val_dense_5_loss: 0.1176 - val_dense_3_acc: 0.8718 - val_dense_4_acc: 0.9544 - val_dense_5_acc: 0.9642
# Epoch 28/30
# 180/180 [==============================] - 53s 292ms/step - loss: 1.0931 - dense_3_loss: 0.6191 - dense_4_loss: 0.2755 - dense_5_loss: 0.1985 - dense_3_acc: 0.8222 - dense_4_acc: 0.9156 - dense_5_acc: 0.9361 - val_loss: 0.8012 - val_dense_3_loss: 0.5078 - val_dense_4_loss: 0.1536 - val_dense_5_loss: 0.1397 - val_dense_3_acc: 0.8618 - val_dense_4_acc: 0.9587 - val_dense_5_acc: 0.9562
# Epoch 29/30
# 180/180 [==============================] - 53s 292ms/step - loss: 0.9798 - dense_3_loss: 0.5500 - dense_4_loss: 0.2498 - dense_5_loss: 0.1800 - dense_3_acc: 0.8398 - dense_4_acc: 0.9247 - dense_5_acc: 0.9430 - val_loss: 0.7389 - val_dense_3_loss: 0.4814 - val_dense_4_loss: 0.1387 - val_dense_5_loss: 0.1189 - val_dense_3_acc: 0.8720 - val_dense_4_acc: 0.9609 - val_dense_5_acc: 0.9619
# Epoch 30/30
# 180/180 [==============================] - 53s 293ms/step - loss: 0.9076 - dense_3_loss: 0.5085 - dense_4_loss: 0.2364 - dense_5_loss: 0.1627 - dense_3_acc: 0.8514 - dense_4_acc: 0.9277 - dense_5_acc: 0.9471 - val_loss: 0.6320 - val_dense_3_loss: 0.4068 - val_dense_4_loss: 0.1246 - val_dense_5_loss: 0.1006 - val_dense_3_acc: 0.8902 - val_dense_4_acc: 0.9647 - val_dense_5_acc: 0.9689
# HBox(children=(IntProgress(value=0, max=50210), HTML(value='')))
# Training images: (50210, 64, 64, 1)
# Training labels root: (50210, 168)
# Training labels vowel: (50210, 11)
# Training labels consonants: (50210, 7)
# Epoch 1/30
# 180/180 [==============================] - 50s 279ms/step - loss: 1.1281 - dense_3_loss: 0.6577 - dense_4_loss: 0.2742 - dense_5_loss: 0.1961 - dense_3_acc: 0.8181 - dense_4_acc: 0.9190 - dense_5_acc: 0.9382 - val_loss: 0.5888 - val_dense_3_loss: 0.3583 - val_dense_4_loss: 0.1356 - val_dense_5_loss: 0.0949 - val_dense_3_acc: 0.8974 - val_dense_4_acc: 0.9634 - val_dense_5_acc: 0.9734
# Epoch 2/30
# 180/180 [==============================] - 51s 281ms/step - loss: 1.0393 - dense_3_loss: 0.6073 - dense_4_loss: 0.2475 - dense_5_loss: 0.1845 - dense_3_acc: 0.8281 - dense_4_acc: 0.9252 - dense_5_acc: 0.9420 - val_loss: 0.5641 - val_dense_3_loss: 0.3504 - val_dense_4_loss: 0.1165 - val_dense_5_loss: 0.0972 - val_dense_3_acc: 0.8954 - val_dense_4_acc: 0.9679 - val_dense_5_acc: 0.9721
# Epoch 3/30
# 180/180 [==============================] - 51s 286ms/step - loss: 1.0951 - dense_3_loss: 0.6301 - dense_4_loss: 0.2663 - dense_5_loss: 0.1987 - dense_3_acc: 0.8231 - dense_4_acc: 0.9194 - dense_5_acc: 0.9370 - val_loss: 0.6768 - val_dense_3_loss: 0.4221 - val_dense_4_loss: 0.1516 - val_dense_5_loss: 0.1032 - val_dense_3_acc: 0.8815 - val_dense_4_acc: 0.9569 - val_dense_5_acc: 0.9699
# Epoch 4/30
# 180/180 [==============================] - 52s 288ms/step - loss: 1.1173 - dense_3_loss: 0.6393 - dense_4_loss: 0.2816 - dense_5_loss: 0.1964 - dense_3_acc: 0.8219 - dense_4_acc: 0.9135 - dense_5_acc: 0.9379 - val_loss: 0.5447 - val_dense_3_loss: 0.3468 - val_dense_4_loss: 0.1102 - val_dense_5_loss: 0.0878 - val_dense_3_acc: 0.8984 - val_dense_4_acc: 0.9699 - val_dense_5_acc: 0.9726
# Epoch 5/30
# 180/180 [==============================] - 52s 290ms/step - loss: 0.9435 - dense_3_loss: 0.5321 - dense_4_loss: 0.2410 - dense_5_loss: 0.1704 - dense_3_acc: 0.8478 - dense_4_acc: 0.9271 - dense_5_acc: 0.9476 - val_loss: 0.5385 - val_dense_3_loss: 0.3326 - val_dense_4_loss: 0.1173 - val_dense_5_loss: 0.0886 - val_dense_3_acc: 0.9047 - val_dense_4_acc: 0.9696 - val_dense_5_acc: 0.9746
# Epoch 6/30
# 180/180 [==============================] - 52s 291ms/step - loss: 0.9284 - dense_3_loss: 0.5251 - dense_4_loss: 0.2381 - dense_5_loss: 0.1651 - dense_3_acc: 0.8497 - dense_4_acc: 0.9277 - dense_5_acc: 0.9475 - val_loss: 0.5728 - val_dense_3_loss: 0.3616 - val_dense_4_loss: 0.1183 - val_dense_5_loss: 0.0930 - val_dense_3_acc: 0.8935 - val_dense_4_acc: 0.9694 - val_dense_5_acc: 0.9741
# Epoch 7/30
# 180/180 [==============================] - 52s 291ms/step - loss: 0.8770 - dense_3_loss: 0.4905 - dense_4_loss: 0.2273 - dense_5_loss: 0.1592 - dense_3_acc: 0.8580 - dense_4_acc: 0.9317 - dense_5_acc: 0.9509 - val_loss: 0.5306 - val_dense_3_loss: 0.3294 - val_dense_4_loss: 0.1193 - val_dense_5_loss: 0.0819 - val_dense_3_acc: 0.9014 - val_dense_4_acc: 0.9659 - val_dense_5_acc: 0.9768
# Epoch 8/30
# 180/180 [==============================] - 53s 292ms/step - loss: 0.8856 - dense_3_loss: 0.4931 - dense_4_loss: 0.2307 - dense_5_loss: 0.1618 - dense_3_acc: 0.8590 - dense_4_acc: 0.9315 - dense_5_acc: 0.9493 - val_loss: 0.5377 - val_dense_3_loss: 0.3316 - val_dense_4_loss: 0.1195 - val_dense_5_loss: 0.0867 - val_dense_3_acc: 0.9039 - val_dense_4_acc: 0.9679 - val_dense_5_acc: 0.9751
# Epoch 9/30
# 180/180 [==============================] - 53s 292ms/step - loss: 0.8827 - dense_3_loss: 0.4920 - dense_4_loss: 0.2302 - dense_5_loss: 0.1605 - dense_3_acc: 0.8583 - dense_4_acc: 0.9298 - dense_5_acc: 0.9502 - val_loss: 0.5618 - val_dense_3_loss: 0.3440 - val_dense_4_loss: 0.1291 - val_dense_5_loss: 0.0886 - val_dense_3_acc: 0.8994 - val_dense_4_acc: 0.9647 - val_dense_5_acc: 0.9741
# Epoch 10/30
# 180/180 [==============================] - 53s 292ms/step - loss: 0.8742 - dense_3_loss: 0.4806 - dense_4_loss: 0.2380 - dense_5_loss: 0.1556 - dense_3_acc: 0.8620 - dense_4_acc: 0.9278 - dense_5_acc: 0.9504 - val_loss: 0.4927 - val_dense_3_loss: 0.3038 - val_dense_4_loss: 0.1086 - val_dense_5_loss: 0.0803 - val_dense_3_acc: 0.9121 - val_dense_4_acc: 0.9736 - val_dense_5_acc: 0.9773
# Epoch 11/30
# 180/180 [==============================] - 53s 293ms/step - loss: 0.8460 - dense_3_loss: 0.4664 - dense_4_loss: 0.2246 - dense_5_loss: 0.1550 - dense_3_acc: 0.8646 - dense_4_acc: 0.9315 - dense_5_acc: 0.9518 - val_loss: 1.0464 - val_dense_3_loss: 0.6861 - val_dense_4_loss: 0.1900 - val_dense_5_loss: 0.1703 - val_dense_3_acc: 0.8066 - val_dense_4_acc: 0.9470 - val_dense_5_acc: 0.9495
# Epoch 12/30
# 180/180 [==============================] - 53s 293ms/step - loss: 1.0196 - dense_3_loss: 0.5740 - dense_4_loss: 0.2595 - dense_5_loss: 0.1861 - dense_3_acc: 0.8368 - dense_4_acc: 0.9219 - dense_5_acc: 0.9419 - val_loss: 0.7071 - val_dense_3_loss: 0.4325 - val_dense_4_loss: 0.1618 - val_dense_5_loss: 0.1128 - val_dense_3_acc: 0.8773 - val_dense_4_acc: 0.9572 - val_dense_5_acc: 0.9689
# Epoch 13/30
# 180/180 [==============================] - 53s 293ms/step - loss: 0.8770 - dense_3_loss: 0.4878 - dense_4_loss: 0.2313 - dense_5_loss: 0.1579 - dense_3_acc: 0.8594 - dense_4_acc: 0.9301 - dense_5_acc: 0.9503 - val_loss: 0.5635 - val_dense_3_loss: 0.3310 - val_dense_4_loss: 0.1422 - val_dense_5_loss: 0.0903 - val_dense_3_acc: 0.9019 - val_dense_4_acc: 0.9637 - val_dense_5_acc: 0.9746
# Epoch 14/30
# 180/180 [==============================] - 53s 292ms/step - loss: 0.7871 - dense_3_loss: 0.4311 - dense_4_loss: 0.2094 - dense_5_loss: 0.1466 - dense_3_acc: 0.8748 - dense_4_acc: 0.9343 - dense_5_acc: 0.9533 - val_loss: 0.5327 - val_dense_3_loss: 0.3280 - val_dense_4_loss: 0.1117 - val_dense_5_loss: 0.0929 - val_dense_3_acc: 0.9076 - val_dense_4_acc: 0.9721 - val_dense_5_acc: 0.9719
# Epoch 15/30
# 180/180 [==============================] - 53s 293ms/step - loss: 0.8793 - dense_3_loss: 0.4910 - dense_4_loss: 0.2280 - dense_5_loss: 0.1603 - dense_3_acc: 0.8574 - dense_4_acc: 0.9317 - dense_5_acc: 0.9497 - val_loss: 0.6704 - val_dense_3_loss: 0.4119 - val_dense_4_loss: 0.1505 - val_dense_5_loss: 0.1080 - val_dense_3_acc: 0.8994 - val_dense_4_acc: 0.9614 - val_dense_5_acc: 0.9719
# Epoch 16/30
# 180/180 [==============================] - 53s 293ms/step - loss: 0.8718 - dense_3_loss: 0.4814 - dense_4_loss: 0.2260 - dense_5_loss: 0.1644 - dense_3_acc: 0.8653 - dense_4_acc: 0.9336 - dense_5_acc: 0.9502 - val_loss: 0.5828 - val_dense_3_loss: 0.3450 - val_dense_4_loss: 0.1456 - val_dense_5_loss: 0.0922 - val_dense_3_acc: 0.9049 - val_dense_4_acc: 0.9622 - val_dense_5_acc: 0.9746
# Epoch 17/30
# 180/180 [==============================] - 53s 293ms/step - loss: 0.8308 - dense_3_loss: 0.4581 - dense_4_loss: 0.2245 - dense_5_loss: 0.1482 - dense_3_acc: 0.8691 - dense_4_acc: 0.9329 - dense_5_acc: 0.9535 - val_loss: 0.5402 - val_dense_3_loss: 0.3329 - val_dense_4_loss: 0.1182 - val_dense_5_loss: 0.0891 - val_dense_3_acc: 0.9037 - val_dense_4_acc: 0.9704 - val_dense_5_acc: 0.9759
# Epoch 18/30
# 180/180 [==============================] - 53s 293ms/step - loss: 0.7614 - dense_3_loss: 0.4223 - dense_4_loss: 0.2011 - dense_5_loss: 0.1380 - dense_3_acc: 0.8790 - dense_4_acc: 0.9396 - dense_5_acc: 0.9579 - val_loss: 0.5495 - val_dense_3_loss: 0.3333 - val_dense_4_loss: 0.1335 - val_dense_5_loss: 0.0827 - val_dense_3_acc: 0.9076 - val_dense_4_acc: 0.9627 - val_dense_5_acc: 0.9786
# Epoch 19/30
# 180/180 [==============================] - 53s 293ms/step - loss: 0.8096 - dense_3_loss: 0.4471 - dense_4_loss: 0.2161 - dense_5_loss: 0.1463 - dense_3_acc: 0.8721 - dense_4_acc: 0.9333 - dense_5_acc: 0.9539 - val_loss: 0.5471 - val_dense_3_loss: 0.3437 - val_dense_4_loss: 0.1148 - val_dense_5_loss: 0.0886 - val_dense_3_acc: 0.9012 - val_dense_4_acc: 0.9709 - val_dense_5_acc: 0.9744
# Epoch 20/30
# 180/180 [==============================] - 53s 292ms/step - loss: 0.8416 - dense_3_loss: 0.4612 - dense_4_loss: 0.2243 - dense_5_loss: 0.1560 - dense_3_acc: 0.8673 - dense_4_acc: 0.9312 - dense_5_acc: 0.9510 - val_loss: 0.5119 - val_dense_3_loss: 0.3101 - val_dense_4_loss: 0.1164 - val_dense_5_loss: 0.0855 - val_dense_3_acc: 0.9101 - val_dense_4_acc: 0.9661 - val_dense_5_acc: 0.9761
# Epoch 21/30
# 180/180 [==============================] - 53s 293ms/step - loss: 0.6766 - dense_3_loss: 0.3695 - dense_4_loss: 0.1850 - dense_5_loss: 0.1221 - dense_3_acc: 0.8906 - dense_4_acc: 0.9439 - dense_5_acc: 0.9618 - val_loss: 0.5896 - val_dense_3_loss: 0.3466 - val_dense_4_loss: 0.1543 - val_dense_5_loss: 0.0887 - val_dense_3_acc: 0.9156 - val_dense_4_acc: 0.9656 - val_dense_5_acc: 0.9786
# Epoch 22/30
# 180/180 [==============================] - 53s 293ms/step - loss: 0.7213 - dense_3_loss: 0.3917 - dense_4_loss: 0.1941 - dense_5_loss: 0.1355 - dense_3_acc: 0.8854 - dense_4_acc: 0.9417 - dense_5_acc: 0.9577 - val_loss: 0.5341 - val_dense_3_loss: 0.3377 - val_dense_4_loss: 0.1073 - val_dense_5_loss: 0.0891 - val_dense_3_acc: 0.9109 - val_dense_4_acc: 0.9711 - val_dense_5_acc: 0.9739
# Epoch 23/30
# 180/180 [==============================] - 53s 293ms/step - loss: 0.7536 - dense_3_loss: 0.4117 - dense_4_loss: 0.2025 - dense_5_loss: 0.1393 - dense_3_acc: 0.8822 - dense_4_acc: 0.9398 - dense_5_acc: 0.9564 - val_loss: 0.4777 - val_dense_3_loss: 0.2944 - val_dense_4_loss: 0.0998 - val_dense_5_loss: 0.0835 - val_dense_3_acc: 0.9176 - val_dense_4_acc: 0.9716 - val_dense_5_acc: 0.9766
# Epoch 24/30
# 180/180 [==============================] - 53s 293ms/step - loss: 0.6866 - dense_3_loss: 0.3655 - dense_4_loss: 0.1922 - dense_5_loss: 0.1288 - dense_3_acc: 0.8936 - dense_4_acc: 0.9414 - dense_5_acc: 0.9601 - val_loss: 0.5064 - val_dense_3_loss: 0.3056 - val_dense_4_loss: 0.1171 - val_dense_5_loss: 0.0837 - val_dense_3_acc: 0.9174 - val_dense_4_acc: 0.9684 - val_dense_5_acc: 0.9786
# Epoch 25/30
# 180/180 [==============================] - 53s 292ms/step - loss: 0.6604 - dense_3_loss: 0.3470 - dense_4_loss: 0.1858 - dense_5_loss: 0.1277 - dense_3_acc: 0.8985 - dense_4_acc: 0.9444 - dense_5_acc: 0.9599 - val_loss: 0.5930 - val_dense_3_loss: 0.3432 - val_dense_4_loss: 0.1467 - val_dense_5_loss: 0.1031 - val_dense_3_acc: 0.9081 - val_dense_4_acc: 0.9594 - val_dense_5_acc: 0.9729
# Epoch 26/30
# 180/180 [==============================] - 53s 294ms/step - loss: 0.7467 - dense_3_loss: 0.3979 - dense_4_loss: 0.2042 - dense_5_loss: 0.1447 - dense_3_acc: 0.8849 - dense_4_acc: 0.9387 - dense_5_acc: 0.9551 - val_loss: 0.4708 - val_dense_3_loss: 0.2989 - val_dense_4_loss: 0.0956 - val_dense_5_loss: 0.0763 - val_dense_3_acc: 0.9176 - val_dense_4_acc: 0.9746 - val_dense_5_acc: 0.9806
# Epoch 27/30
# 180/180 [==============================] - 53s 293ms/step - loss: 0.6319 - dense_3_loss: 0.3381 - dense_4_loss: 0.1760 - dense_5_loss: 0.1178 - dense_3_acc: 0.8995 - dense_4_acc: 0.9475 - dense_5_acc: 0.9635 - val_loss: 0.5182 - val_dense_3_loss: 0.3269 - val_dense_4_loss: 0.1110 - val_dense_5_loss: 0.0804 - val_dense_3_acc: 0.9206 - val_dense_4_acc: 0.9761 - val_dense_5_acc: 0.9783
# Epoch 28/30
# 180/180 [==============================] - 53s 292ms/step - loss: 1.0973 - dense_3_loss: 0.6326 - dense_4_loss: 0.2707 - dense_5_loss: 0.1940 - dense_3_acc: 0.8252 - dense_4_acc: 0.9197 - dense_5_acc: 0.9394 - val_loss: 0.5328 - val_dense_3_loss: 0.3343 - val_dense_4_loss: 0.1072 - val_dense_5_loss: 0.0913 - val_dense_3_acc: 0.9039 - val_dense_4_acc: 0.9701 - val_dense_5_acc: 0.9724
# Epoch 29/30
# 180/180 [==============================] - 53s 292ms/step - loss: 0.6896 - dense_3_loss: 0.3753 - dense_4_loss: 0.1855 - dense_5_loss: 0.1287 - dense_3_acc: 0.8907 - dense_4_acc: 0.9438 - dense_5_acc: 0.9592 - val_loss: 0.4817 - val_dense_3_loss: 0.2984 - val_dense_4_loss: 0.0986 - val_dense_5_loss: 0.0847 - val_dense_3_acc: 0.9203 - val_dense_4_acc: 0.9726 - val_dense_5_acc: 0.9761
# Epoch 30/30
# 180/180 [==============================] - 52s 291ms/step - loss: 0.6251 - dense_3_loss: 0.3323 - dense_4_loss: 0.1726 - dense_5_loss: 0.1202 - dense_3_acc: 0.9014 - dense_4_acc: 0.9483 - dense_5_acc: 0.9611 - val_loss: 0.5289 - val_dense_3_loss: 0.3376 - val_dense_4_loss: 0.1040 - val_dense_5_loss: 0.0873 - val_dense_3_acc: 0.9126 - val_dense_4_acc: 0.9749 - val_dense_5_acc: 0.9754
# HBox(children=(IntProgress(value=0, max=50210), HTML(value='')))
# Training images: (50210, 64, 64, 1)
# Training labels root: (50210, 168)
# Training labels vowel: (50210, 11)
# Training labels consonants: (50210, 7)
# Epoch 1/30
# 180/180 [==============================] - 50s 280ms/step - loss: 0.9345 - dense_3_loss: 0.5359 - dense_4_loss: 0.2322 - dense_5_loss: 0.1663 - dense_3_acc: 0.8525 - dense_4_acc: 0.9322 - dense_5_acc: 0.9492 - val_loss: 0.4825 - val_dense_3_loss: 0.2910 - val_dense_4_loss: 0.0910 - val_dense_5_loss: 0.1005 - val_dense_3_acc: 0.9238 - val_dense_4_acc: 0.9759 - val_dense_5_acc: 0.9699
# Epoch 2/30
# 180/180 [==============================] - 51s 282ms/step - loss: 0.8891 - dense_3_loss: 0.5068 - dense_4_loss: 0.2267 - dense_5_loss: 0.1556 - dense_3_acc: 0.8596 - dense_4_acc: 0.9319 - dense_5_acc: 0.9524 - val_loss: 0.5523 - val_dense_3_loss: 0.3438 - val_dense_4_loss: 0.1021 - val_dense_5_loss: 0.1064 - val_dense_3_acc: 0.9208 - val_dense_4_acc: 0.9714 - val_dense_5_acc: 0.9721
# Epoch 3/30
# 180/180 [==============================] - 52s 286ms/step - loss: 0.8535 - dense_3_loss: 0.4802 - dense_4_loss: 0.2177 - dense_5_loss: 0.1555 - dense_3_acc: 0.8655 - dense_4_acc: 0.9336 - dense_5_acc: 0.9520 - val_loss: 0.4749 - val_dense_3_loss: 0.2871 - val_dense_4_loss: 0.0994 - val_dense_5_loss: 0.0884 - val_dense_3_acc: 0.9198 - val_dense_4_acc: 0.9751 - val_dense_5_acc: 0.9751
# Epoch 4/30
# 180/180 [==============================] - 52s 289ms/step - loss: 0.8219 - dense_3_loss: 0.4578 - dense_4_loss: 0.2158 - dense_5_loss: 0.1483 - dense_3_acc: 0.8711 - dense_4_acc: 0.9350 - dense_5_acc: 0.9542 - val_loss: 0.4855 - val_dense_3_loss: 0.3024 - val_dense_4_loss: 0.0945 - val_dense_5_loss: 0.0886 - val_dense_3_acc: 0.9188 - val_dense_4_acc: 0.9764 - val_dense_5_acc: 0.9751
# Epoch 5/30
# 180/180 [==============================] - 52s 290ms/step - loss: 0.7113 - dense_3_loss: 0.3941 - dense_4_loss: 0.1852 - dense_5_loss: 0.1320 - dense_3_acc: 0.8870 - dense_4_acc: 0.9441 - dense_5_acc: 0.9589 - val_loss: 0.4661 - val_dense_3_loss: 0.2757 - val_dense_4_loss: 0.1043 - val_dense_5_loss: 0.0862 - val_dense_3_acc: 0.9276 - val_dense_4_acc: 0.9729 - val_dense_5_acc: 0.9756
# Epoch 6/30
# 180/180 [==============================] - 52s 291ms/step - loss: 0.6922 - dense_3_loss: 0.3764 - dense_4_loss: 0.1866 - dense_5_loss: 0.1293 - dense_3_acc: 0.8939 - dense_4_acc: 0.9440 - dense_5_acc: 0.9603 - val_loss: 0.5438 - val_dense_3_loss: 0.3080 - val_dense_4_loss: 0.1334 - val_dense_5_loss: 0.1025 - val_dense_3_acc: 0.9216 - val_dense_4_acc: 0.9647 - val_dense_5_acc: 0.9681
# Epoch 7/30
# 180/180 [==============================] - 53s 292ms/step - loss: 0.7724 - dense_3_loss: 0.4281 - dense_4_loss: 0.1998 - dense_5_loss: 0.1445 - dense_3_acc: 0.8787 - dense_4_acc: 0.9389 - dense_5_acc: 0.9547 - val_loss: 0.4667 - val_dense_3_loss: 0.2805 - val_dense_4_loss: 0.0960 - val_dense_5_loss: 0.0902 - val_dense_3_acc: 0.9248 - val_dense_4_acc: 0.9764 - val_dense_5_acc: 0.9716
# Epoch 8/30
# 180/180 [==============================] - 53s 292ms/step - loss: 0.7003 - dense_3_loss: 0.3793 - dense_4_loss: 0.1874 - dense_5_loss: 0.1336 - dense_3_acc: 0.8919 - dense_4_acc: 0.9433 - dense_5_acc: 0.9582 - val_loss: 0.4977 - val_dense_3_loss: 0.2902 - val_dense_4_loss: 0.1193 - val_dense_5_loss: 0.0882 - val_dense_3_acc: 0.9208 - val_dense_4_acc: 0.9671 - val_dense_5_acc: 0.9749
# Epoch 9/30
# 180/180 [==============================] - 53s 293ms/step - loss: 1.1732 - dense_3_loss: 0.6516 - dense_4_loss: 0.3137 - dense_5_loss: 0.2078 - dense_3_acc: 0.8282 - dense_4_acc: 0.9039 - dense_5_acc: 0.9373 - val_loss: 0.5719 - val_dense_3_loss: 0.3472 - val_dense_4_loss: 0.1247 - val_dense_5_loss: 0.1001 - val_dense_3_acc: 0.9079 - val_dense_4_acc: 0.9651 - val_dense_5_acc: 0.9661
# Epoch 10/30
# 180/180 [==============================] - 53s 294ms/step - loss: 0.7909 - dense_3_loss: 0.4299 - dense_4_loss: 0.2162 - dense_5_loss: 0.1448 - dense_3_acc: 0.8772 - dense_4_acc: 0.9342 - dense_5_acc: 0.9536 - val_loss: 0.4854 - val_dense_3_loss: 0.2809 - val_dense_4_loss: 0.1111 - val_dense_5_loss: 0.0935 - val_dense_3_acc: 0.9243 - val_dense_4_acc: 0.9711 - val_dense_5_acc: 0.9714
# Epoch 11/30
# 180/180 [==============================] - 53s 293ms/step - loss: 0.7530 - dense_3_loss: 0.4105 - dense_4_loss: 0.2047 - dense_5_loss: 0.1378 - dense_3_acc: 0.8829 - dense_4_acc: 0.9373 - dense_5_acc: 0.9570 - val_loss: 0.4644 - val_dense_3_loss: 0.2744 - val_dense_4_loss: 0.1053 - val_dense_5_loss: 0.0846 - val_dense_3_acc: 0.9223 - val_dense_4_acc: 0.9721 - val_dense_5_acc: 0.9749
# Epoch 12/30
# 180/180 [==============================] - 53s 292ms/step - loss: 0.6996 - dense_3_loss: 0.3742 - dense_4_loss: 0.1923 - dense_5_loss: 0.1332 - dense_3_acc: 0.8906 - dense_4_acc: 0.9406 - dense_5_acc: 0.9584 - val_loss: 0.4814 - val_dense_3_loss: 0.2901 - val_dense_4_loss: 0.1083 - val_dense_5_loss: 0.0829 - val_dense_3_acc: 0.9233 - val_dense_4_acc: 0.9751 - val_dense_5_acc: 0.9783
# Epoch 13/30
# 180/180 [==============================] - 52s 291ms/step - loss: 0.6337 - dense_3_loss: 0.3335 - dense_4_loss: 0.1772 - dense_5_loss: 0.1230 - dense_3_acc: 0.9032 - dense_4_acc: 0.9458 - dense_5_acc: 0.9619 - val_loss: 0.4747 - val_dense_3_loss: 0.2800 - val_dense_4_loss: 0.1037 - val_dense_5_loss: 0.0910 - val_dense_3_acc: 0.9211 - val_dense_4_acc: 0.9726 - val_dense_5_acc: 0.9716
# Epoch 14/30
# 180/180 [==============================] - 52s 291ms/step - loss: 0.6192 - dense_3_loss: 0.3313 - dense_4_loss: 0.1733 - dense_5_loss: 0.1146 - dense_3_acc: 0.9036 - dense_4_acc: 0.9487 - dense_5_acc: 0.9644 - val_loss: 0.5001 - val_dense_3_loss: 0.3042 - val_dense_4_loss: 0.1073 - val_dense_5_loss: 0.0886 - val_dense_3_acc: 0.9216 - val_dense_4_acc: 0.9736 - val_dense_5_acc: 0.9741
# Epoch 15/30
# 180/180 [==============================] - 53s 292ms/step - loss: 0.6236 - dense_3_loss: 0.3337 - dense_4_loss: 0.1730 - dense_5_loss: 0.1169 - dense_3_acc: 0.9023 - dense_4_acc: 0.9478 - dense_5_acc: 0.9634 - val_loss: 0.4479 - val_dense_3_loss: 0.2805 - val_dense_4_loss: 0.0880 - val_dense_5_loss: 0.0793 - val_dense_3_acc: 0.9231 - val_dense_4_acc: 0.9796 - val_dense_5_acc: 0.9761
# Epoch 16/30
# 180/180 [==============================] - 53s 293ms/step - loss: 0.6029 - dense_3_loss: 0.3169 - dense_4_loss: 0.1718 - dense_5_loss: 0.1142 - dense_3_acc: 0.9065 - dense_4_acc: 0.9485 - dense_5_acc: 0.9648 - val_loss: 0.5206 - val_dense_3_loss: 0.3275 - val_dense_4_loss: 0.0983 - val_dense_5_loss: 0.0948 - val_dense_3_acc: 0.9183 - val_dense_4_acc: 0.9741 - val_dense_5_acc: 0.9754
# Epoch 17/30
# 180/180 [==============================] - 53s 293ms/step - loss: 0.6589 - dense_3_loss: 0.3555 - dense_4_loss: 0.1839 - dense_5_loss: 0.1195 - dense_3_acc: 0.8998 - dense_4_acc: 0.9454 - dense_5_acc: 0.9654 - val_loss: 0.5673 - val_dense_3_loss: 0.3471 - val_dense_4_loss: 0.1128 - val_dense_5_loss: 0.1073 - val_dense_3_acc: 0.9198 - val_dense_4_acc: 0.9736 - val_dense_5_acc: 0.9699
# Epoch 18/30
#  66/180 [==========>...................] - ETA: 32s - loss: 0.6885 - dense_3_loss: 0.3712 - dense_4_loss: 0.1874 - dense_5_loss: 0.1298 - dense_3_acc: 0.8979 - dense_4_acc: 0.9424 - dense_5_acc: 0.9610

# %%
# %matplotlib inline
def plot_loss(his, epoch, title):
    plt.style.use('ggplot')
    plt.figure()
    plt.plot(np.arange(0, epoch), his.history['loss'], label='train_loss')
    plt.plot(np.arange(0, epoch), his.history['dense_3_loss'], label='train_root_loss')
    plt.plot(np.arange(0, epoch), his.history['dense_4_loss'], label='train_vowel_loss')
    plt.plot(np.arange(0, epoch), his.history['dense_5_loss'], label='train_consonant_loss')
    
    plt.plot(np.arange(0, epoch), his.history['val_dense_3_loss'], label='val_train_root_loss')
    plt.plot(np.arange(0, epoch), his.history['val_dense_4_loss'], label='val_train_vowel_loss')
    plt.plot(np.arange(0, epoch), his.history['val_dense_5_loss'], label='val_train_consonant_loss')
    
    plt.title(title)
    plt.xlabel('Epoch #')
    plt.ylabel('Loss')
    plt.legend(loc='upper right')
    plt.show()

def plot_acc(his, epoch, title):
    plt.style.use('ggplot')
    plt.figure()
    plt.plot(np.arange(0, epoch), his.history['dense_3_accuracy'], label='train_root_acc')
    plt.plot(np.arange(0, epoch), his.history['dense_4_accuracy'], label='train_vowel_accuracy')
    plt.plot(np.arange(0, epoch), his.history['dense_5_accuracy'], label='train_consonant_accuracy')
    
    plt.plot(np.arange(0, epoch), his.history['val_dense_3_accuracy'], label='val_root_acc')
    plt.plot(np.arange(0, epoch), his.history['val_dense_4_accuracy'], label='val_vowel_accuracy')
    plt.plot(np.arange(0, epoch), his.history['val_dense_5_accuracy'], label='val_consonant_accuracy')
    plt.title(title)
    plt.xlabel('Epoch #')
    plt.ylabel('Accuracy')
    plt.legend(loc='upper right')
    plt.show()

# %%
for dataset in range(4):
    plot_loss(histories[dataset], epochs, f'Training Dataset: {dataset}')
    plot_acc(histories[dataset], epochs, f'Training Dataset: {dataset}')

# %%
del histories
gc.collect()

# %%
preds_dict = {
    'grapheme_root': [],
    'vowel_diacritic': [],
    'consonant_diacritic': []
}

# %%
components = ['consonant_diacritic', 'grapheme_root', 'vowel_diacritic']
target=[] # model predictions placeholder
row_id=[] # row_id place holder
for i in range(4):
    df_test_img = pd.read_parquet(dataset_dir + '/test_image_data_{}.parquet'.format(i)) 
    df_test_img.set_index('image_id', inplace=True)

    X_test = resize(df_test_img, need_progress_bar=False)/255
    X_test = X_test.values.reshape(-1, IMG_SIZE, IMG_SIZE, N_CHANNELS)
    
    preds = model.predict(X_test)

    for i, p in enumerate(preds_dict):
        preds_dict[p] = np.argmax(preds[i], axis=1)

    for k,id in enumerate(df_test_img.index.values):  
        for i,comp in enumerate(components):
            id_sample=id+'_'+comp
            row_id.append(id_sample)
            target.append(preds_dict[comp][k])
    del df_test_img
    del X_test
    gc.collect()

df_sample = pd.DataFrame(
    {
        'row_id': row_id,
        'target':target
    },
    columns = ['row_id','target'] 
)
df_sample.to_csv('submission.csv',index=False)
df_sample.head()
